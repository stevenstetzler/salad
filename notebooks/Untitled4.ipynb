# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data = """
3|92
13|92
16|92
20|92
21|8
32|92
45|92
"""
list(map(lambda x : x.split("|"), data.split("\n")))
# Out:
# [[''],
#  ['3', '92'],
#  ['13', '92'],
#  ['16', '92'],
#  ['20', '92'],
#  ['21', '8'],
#  ['32', '92'],
#  ['45', '92'],
#  ['']]

# %%
night = [
    3, 13, 16, 20, 21, 32, 45
]
num_obs = [
    92, 92, 92, 92, 8, 92, 92
]

# %%
import matplotlib
matplotlib.rcParams.update({'font.size': 12})

fig = plt.figure(dpi=150)
plt.bar(night, num_obs)
plt.xlabel("night of survey")
plt.ylabel("number of images")
plt.title("LSST Observations of COSMOS field; Ecliptic latitude -9.39$^\circ$")
plt.show()
