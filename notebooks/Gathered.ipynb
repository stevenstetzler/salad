# %%
from salad.cluster import Clusters
from salad.regression import regression
import matplotlib.pyplot as plt

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_5/gather.pkl")

# %%
def plot_cluster(cluster):
    p = cluster.points
    x, y = p[:, 2][:, None], p[:, :2]
#     regression_result = regression(x, y)
    plt.scatter(y[:, 0], y[:, 1], c=x[:, 0], s=1)
    
def plot_result(result, x):
    _x = np.linspace(x.min(), x.max(), 100)[:, None]
    _y = _x @ result.beta + regression_result.alpha
    plt.plot(_y[:, 0], _y[:, 1])
    
def filter_velocity(cluster, vmin=0.1, vmax=0.5):
    p = cluster.points
    x, y = p[:, 2][:, None], p[:, :2]
    regression_result = regression(x, y)
    v = (regression_result.beta**2).sum()**0.5
    return (v > vmin) and (v <= vmax)

def filter_n(cluster, n=15):
    return len(cluster.points) >= n

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_5/gather.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))
fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=5")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_5/gather_2.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))
fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=5")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_4/gather.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=4")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_4/gather_2.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=4")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_3/gather.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=3")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/DEEP/20190403/A0c/detector_1/snr_3/gather_2.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=3")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/tmp/DEEP/20190403/A0c/detector_1/snr_3/gather_2.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=3")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/tmp/DEEP/20190403/A0c/detector_1/snr_2.5/gather_2.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=2.5")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/tmp/DEEP/20190403/A0c/detector_1/snr_2/gather_2.pkl")
clusters = filter(filter_velocity, filter(filter_n, clusters))

fig = plt.figure(facecolor='white', dpi=150)
for cluster in clusters:
    plot_cluster(cluster)
plt.xlabel("RA")
plt.ylabel("DEC")
plt.title("SNR=2")
plt.show()

# %%
clusters = Clusters.read("/epyc/projects/salad/search/tmp/DEEP/20190403/A0c/detector_1/snr_2/gather_2.pkl")
clusters = list(filter(filter_velocity, filter(filter_n, clusters)))
